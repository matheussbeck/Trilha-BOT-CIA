# %%
print('='*30)
print('CALCULADORA CIA BOT')
print('='*30)

n1 = n2= 0
while True:
 n1 = int(input('Digite um número: '))
 n2 = int(input('Digite mais um número: '))
 print (f'Você digitou os números {n1} e {n2}')
 print (f'O resultado da soma é {n1+n2}')
 print (f'O resultado da subtração é {n1-n2}')
 print (f'O resultado da multiplicação é {n1*n2}')
 print (f'O resultado da divisão é {n1/n2}')
 r = str(input('Deseja Calcular novamente ? [S/N] ')).strip().upper()
 if r not in 'SN':
  r = str(input('Esta resposta nao é válida. Deseja Calcular novamente ? [S/N] '))
 if r == 'N':
  break
print('Calculadora encerrada !')
# Out:
# ...
# CALCULADORA CIA BOT
# ...
# Digite um número: 5
# Digite mais um número: 10
# Você digitou os números 5 e 10
# O resultado da soma é 15
# O resultado da subtração é -5
# O resultado da multiplicação é 50
# O resultado da divisão é 0.5
# Deseja Calcular novamente ? [S/N] k
# Esta resposta nao é válida. Deseja Calcular novamente ? [S/N] s
# Digite um número: 7
# Digite mais um número: 8
# Você digitou os números 7 e 8
# O resultado da soma é 15
# O resultado da subtração é -1
# O resultado da multiplicação é 56
# O resultado da divisão é 0.875
# Deseja Calcular novamente ? [S/N] n
# Calculadora encerrada !

# %%
print('='*30)
print('PAR OU IMPAR ?')
print('='*30)

n1 = 0
while True:
 n1 = int(input('Digite um número: '))
 if n1 % 2 == 0:
  print(f'O número {n1} é PAR')
 else:
  print(f'O número {n1} é IMPAR')
 r = str(input('Deseja Calcular novamente ? [S/N] ')).strip().upper()
 if r not in 'SN':
  r = str(input('Esta resposta nao é válida. Deseja Calcular novamente ? [S/N] ')).strip().upper()
 if r == 'N':
  break
print('PAR OU IMPAR encerrado !')
# Out:
# ...
# PAR OU IMPAR ?
# ...
# Digite um número: 5
# O número 5 é IMPAR
# Deseja Calcular novamente ? [S/N] n
# PAR OU IMPAR encerrado !
